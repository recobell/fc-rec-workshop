# %% [markdown]
# # Database Initialization

# %% [markdown]
# 확장 기능 로드

# %%
# %reload_ext sql
# %run libdb.py

# %% [markdown]
# 데이터베이스 접속

# %%
# postgresql+psycopg2://사용자ID:password@127.0.0.1:5432/데이터베이스
# %sql postgresql+psycopg2://postgres:@127.0.0.1:5432/postgres
# Out:
# 'Connected: postgres@postgres'

# %% [markdown]
# ## Initialze Query for PAKDD e-Commerce User Behavior
#
# You should downlaod followings
#
# 1. site_view_log => http://pakdd2017.recobell.io/site_view_log_small.csv000.gz
# 2. site_order_log => http://pakdd2017.recobell.io/site_order_log_small.csv000.gz
# 3. site_product => http://pakdd2017.recobell.io/site_product_w_img.csv000.gz
#
# then un-zip all files, move it to [FILE_DIRECTORY], which you want to keep it

# %%
# %%sql
# drop table if exists site_view_log;
#
# create table site_view_log (
#     server_time timestamp,
#     device char(2),
#     session_id char(10),
#     uid char(7),
#     item_id char(7)
# );
#
# drop table if exists site_order_log;
#
# create table site_order_log (
#     server_time timestamp,
#     device char(2),
#     session_id char(10),
#     uid char(7),
#     item_id char(7),
#     order_id char(7),
#     quantity int
# );
#
#
# drop table if exists site_product;
#
# create table site_product (
#     item_id    char(7),
#     item_image    varchar(255),
#     price    int,
#     category1    char(7),
#     category2    char(7),
#     category3    char(7),
#     category4    char(7),
#     brand        char(7)
# );
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ## Copy Data from File to Table

# %%
# Set the FILE_DIRECTORY
FILE_DIRECTORY = '/Users/jonghm/Data/dataset'
view_file = FILE_DIRECTORY+'/site_view_log_small.csv000'
order_file = FILE_DIRECTORY+'/site_order_log_small.csv000'
product_file = FILE_DIRECTORY+'/site_product_w_img.csv000'

# %%
# %%sql
# copy site_view_log
# from :view_file
# CSV;
#
# copy site_order_log
# from :order_file
# CSV;
#
# copy site_product
# from :product_file
# CSV;
# Out:
# 13461897 rows affected.
# 1084109 rows affected.
# 422880 rows affected.
# []

# %%
# %sql select * from site_view_log limit 100;
# Out:
# 100 rows affected.
# [(datetime.datetime(2016, 9, 29, 10, 59, 21, 694000), 'MA', 'r3jbBBHfMI', '1dbe8cd', 'cccda36'),
#  (datetime.datetime(2016, 9, 29, 0, 3, 51, 319000), 'MA', 'UBn2wub6Ry', '320fc44', '01196d7'),
#  (datetime.datetime(2016, 9, 16, 13, 25, 21, 267000), 'MA', 'Xox6XUgZdv', '320fc44', '01196d7'),
#  (datetime.datetime(2016, 9, 16, 13, 25, 34, 877000), 'MA', 'Xox6XUgZdv', '320fc44', '01196d7'),
#  (datetime.datetime(2016, 9, 29, 23, 25, 9, 985000), 'MA', 'H2KNgUviPF', '578786a', '0b595b7'),
#  (datetime.datetime(2016, 9, 25, 16, 45, 32, 96000), 'MA', 'lGtBvOozJB', '578786a', '04c6c53'),
#  (datetime.datetime(2016, 9, 17, 0, 52, 4, 819000), 'MA', 'hI3sRu6wdi', '578786a', '73d826f'),
#  (datetime.datetime(2016, 9, 25, 23, 0, 58, 606000), 'MA', 'bA8lNoqakQ', '8007201', 'cffaca1'),
#  (datetime.datetime(2016, 10, 1, 6, 39, 50, 250000), 'MA', 'DcaHbyAwg7', '99055ba', '435b1c0'),
# ...

# %%
# %sql select * from site_order_log limit 100;
# Out:
# 100 rows affected.
# [(datetime.datetime(2016, 9, 20, 19, 6, 58, 919000), 'MA', 'mu7BVl3Z3U', '7e525ea', '38f9c44', 'fa8ccb5', 1),
#  (datetime.datetime(2016, 9, 20, 18, 35, 5, 596000), 'MA', 'YBWBm4JgxM', 'c6a054f', '89ef3c8', 'ffdef9b', 1),
#  (datetime.datetime(2016, 9, 18, 13, 56, 16, 843000), 'MA', 'qMjSVaRf9C', 'b72ded7', '5724f59', '6d60b22', 1),
#  (datetime.datetime(2016, 9, 30, 19, 27, 53, 832000), 'MA', 'zHwBtDTdK5', 'b41d588', 'e446438', '920726e', 1),
#  (datetime.datetime(2016, 9, 28, 17, 13, 15, 295000), 'MA', 'MgWfzwScLb', '9f66b15', '896ab89', '638657d', 1),
#  (datetime.datetime(2016, 9, 27, 18, 5, 21, 828000), 'MA', 'ZaTTDwvNWh', '9c3916f', '337d12c', '00f0395', 1),
#  (datetime.datetime(2016, 9, 22, 22, 17, 48, 149000), 'MA', 'NI7PERtXe0', '116af04', '1662ce4', '7b9d1d0', 1),
#  (datetime.datetime(2016, 9, 18, 10, 0, 58, 368000), 'MA', 'REetvqFk9s', '9a78fa1', '00d6a06', '15e1fa8', 1),
# ...

# %%
# %sql select * from site_product limit 100;
# Out:
# 100 rows affected.
# [('d6f1102', 'http://fc-img.recobell.io/images/goods/313/12061313_h.jpg', 266310, '256e556', '5c0a3a9', 'aaba489', '631746e', '1e8d744'),
#  ('dd20ba1', 'http://fc-img.recobell.io/images/goods/598/11844598_h.jpg', 17600, 'c9de0e0', 'aef1a1e', '21b0f94', 'c8e8345', '5c7ad42'),
#  ('bcf2618', 'http://fc-img.recobell.io/images/goods/454/11462454_h.jpg', 209000, '256e556', '94e6f94', '5061aaa', '5061aaa', 'f9eb29f'),
#  ('ec83ae8', 'http://fc-img.recobell.io/images/goods/623/12335623_h.jpg', 18500, 'c9de0e0', 'aef1a1e', '21b0f94', '78d2bb5', '0b7a648'),
#  ('e6335a3', 'http://fc-img.recobell.io/images/goods/490/11458490_h.jpg', 156800, '256e556', 'c317f9c', 'c317f9c', '2761ef3', '7d0baa2'),
#  ('fbd9ca0', 'http://fc-img.recobell.io/images/goods/134/11782134_h.jpg', 8910, 'a3cf17c', 'd83f158', 'afc6fd0', 'ea7780c', 'cdc41f6'),
#  ('6d18009', 'http://fc-img.recobell.io/images/goods/704/12036704_h.jpg', 2500, 'a3cf17c', '4c2d9b5', 'dbe3c1f', '72db833', '2d9021b'),
# ...

# %%
result = %sql select item_id, item_image, price, category1, category2, category3, category4, brand from site_product  limit 10 offset 10;
# Out:
# 10 rows affected.

# %% [markdown]
# Or use _ to store last results

# %%
# %%sql
# select item_id, item_image, price, category1, category2, category3, category4, brand
# from site_product
# limit 10 offset 10
# Out:
# 10 rows affected.
# [('defc461', 'http://fc-img.recobell.io/images/goods/817/12173817_h.jpg', 62100, 'ad36a3e', '96ff299', '8543026', '43277ce', '9370989'),
#  ('b15e68b', 'http://fc-img.recobell.io/images/goods/218/12306218_h.jpg', 48060, 'fad25d1', '8b069cc', '741451c', '8e3fd54', '44650a9'),
#  ('acff3c6', 'http://fc-img.recobell.io/images/goods/619/12292619_h.jpg', 15800, 'aa9d7df', '3e64c1a', '6a9e00f', 'f8435cd', '0560600'),
#  ('a51d30f', 'http://fc-img.recobell.io/images/goods/292/12265292_h.jpg', 110000, 'd9b6b5c', 'f3cebdc', '67f6e23', '21f8467', '37477e7'),
#  ('342dda6', 'http://fc-img.recobell.io/images/goods/736/12302736_h.jpg', 51900, 'c12d0e1', 'a900bfa', 'f44d544', '4879c5b', '883a5c0'),
#  ('4e0705e', 'http://fc-img.recobell.io/images/goods/635/12295635_h.jpg', 98000, 'fad25d1', '8b069cc', 'd9fb088', '9c67588', '38c24bb'),
#  ('aaca7e3', 'http://fc-img.recobell.io/images/goods/068/11337068_h.jpg', 3600, 'd9b6b5c', 'f3cebdc', '67f6e23', '569e0b6', 'aca91b1'),
# ...

# %%
result2 = _
result2
# Out:
# [('defc461', 'http://fc-img.recobell.io/images/goods/817/12173817_h.jpg', 62100, 'ad36a3e', '96ff299', '8543026', '43277ce', '9370989'),
#  ('b15e68b', 'http://fc-img.recobell.io/images/goods/218/12306218_h.jpg', 48060, 'fad25d1', '8b069cc', '741451c', '8e3fd54', '44650a9'),
#  ('acff3c6', 'http://fc-img.recobell.io/images/goods/619/12292619_h.jpg', 15800, 'aa9d7df', '3e64c1a', '6a9e00f', 'f8435cd', '0560600'),
#  ('a51d30f', 'http://fc-img.recobell.io/images/goods/292/12265292_h.jpg', 110000, 'd9b6b5c', 'f3cebdc', '67f6e23', '21f8467', '37477e7'),
#  ('342dda6', 'http://fc-img.recobell.io/images/goods/736/12302736_h.jpg', 51900, 'c12d0e1', 'a900bfa', 'f44d544', '4879c5b', '883a5c0'),
#  ('4e0705e', 'http://fc-img.recobell.io/images/goods/635/12295635_h.jpg', 98000, 'fad25d1', '8b069cc', 'd9fb088', '9c67588', '38c24bb'),
#  ('aaca7e3', 'http://fc-img.recobell.io/images/goods/068/11337068_h.jpg', 3600, 'd9b6b5c', 'f3cebdc', '67f6e23', '569e0b6', 'aca91b1'),
# ...

# %%
images = [x['item_image'] for x in result2]
displayImageUrls(images)
# Out:
# <img src='http://fc-img.recobell.io/images/goods/817/12173817_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/218/12306218_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/619/12292619_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/292/12265292_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/736/12302736_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/635/12295635_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/068/11337068_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/061/12364061_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/676/12171676_h.jpg' width='170' style='display:inline-block'><img src
# ...

# %%
displayImageUrls(getImageUrls(result2, 'item_image'))
# Out:
# <img src='http://fc-img.recobell.io/images/goods/817/12173817_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/218/12306218_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/619/12292619_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/292/12265292_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/736/12302736_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/635/12295635_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/068/11337068_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/061/12364061_h.jpg' width='170' style='display:inline-block'><img src='http://fc-img.recobell.io/images/goods/676/12171676_h.jpg' width='170' style='display:inline-block'><img src
# ...
